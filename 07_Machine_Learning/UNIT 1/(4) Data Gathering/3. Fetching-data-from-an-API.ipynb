# %%
import pandas as pd
import requests

# %%
import requests

url = "https://api.themoviedb.org/3/movie/top_rated"

params = {
    "api_key": "fab93650a0ae7fa86f4baa9e0796a145",
    "language": "en-US",
    "page": 1
}

response = requests.get(url, params=params)

print(response.status_code)
print(response.json())
# Out:
# 200
# ...

# %%
pd.DataFrame(response.json()['results']).head(2)
# Out:
#    adult                     backdrop_path            genre_ids       id  \
# 0  False   /zMwhWailP1WY7sb6AoE6b8ugoy.jpg  [12, 16, 10751, 14]  1007757
# 1  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg             [18, 80]      278
#
#                       title original_language            original_title  \
# 0                   Swapped                en                   Swapped
# 1  The Shawshank Redemption                en  The Shawshank Redemption
#
#                                             overview  popularity  \
# 0  A small woodland creature and a majestic bird,...    184.1031
# 1  Imprisoned in the 1940s for the double murder ...     90.5775
#
#                         poster_path release_date  softcore  video  \
# 0  /tHhxWxge06goXU6ZQH1hj7vK8Hd.jpg   2026-05-01     False  False
# 1  /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23     False  False
#
#    vote_average  vote_count
# 0         9.000        1656
# 1         8.722       30538

# %%
df = pd.DataFrame(response.json()['results'])[['id','title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']]
df
# Out:
#          id                                          title  \
# 0   1007757                                        Swapped
# 1       278                       The Shawshank Redemption
# 2       238                                  The Godfather
# 3    687163                              Project Hail Mary
# 4       240                          The Godfather Part II
# 5   1330021                    Remarkably Bright Creatures
# 6       424                               Schindler's List
# 7       389                                   12 Angry Men
# 8       129                                  Spirited Away
# 9       155                                The Dark Knight
# 10    19404                    Dilwale Dulhania Le Jayenge
# 11   936075                                        Michael
# 12      497                                 The Green Mile
# 13      122  The Lord of the Rings: The Return of the King
# 14   496243                                       Parasite
# ...

# %%
df.shape
# Out:
# (20, 7)

# %%
import pandas as pd
import requests

dfs = []

for i in range(1, 20):
    url = "https://api.themoviedb.org/3/movie/top_rated"

    params = {
        "api_key": "fab93650a0ae7fa86f4baa9e0796a145",
        "language": "en-US",
        "page": i
    }

    while True:
        try:
            response = requests.get(url, params=params)
            break
        except:
            print(f"Retrying page {i}...")

    temp_df = pd.DataFrame(response.json()['results'])[
        ['id', 'title', 'overview', 'release_date',
         'popularity', 'vote_average', 'vote_count']
    ]

    dfs.append(temp_df)

df = pd.concat(dfs, ignore_index=True)
# Out:
# Retrying page 1...
# Retrying page 1...
# Retrying page 1...
# Retrying page 2...
# Retrying page 3...
# Retrying page 6...
# Retrying page 8...
# Retrying page 9...
# Retrying page 9...
# Retrying page 9...
# Retrying page 10...
# Retrying page 10...
# Retrying page 10...
# Retrying page 10...
# Retrying page 10...
# Retrying page 12...
# Retrying page 15...
# Retrying page 17...
# Retrying page 18...
# Retrying page 18...
# Retrying page 18...
# Retrying page 18...
# Retrying page 18...
# Retrying page 19...
# Retrying page 19...
# Retrying page 19...
# Retrying page 19...

# %%
dfs
# Out:
# [         id                                          title  \
#  0   1007757                                        Swapped
#  1       278                       The Shawshank Redemption
#  2       238                                  The Godfather
#  3    687163                              Project Hail Mary
#  4       240                          The Godfather Part II
#  5   1330021                    Remarkably Bright Creatures
#  6       424                               Schindler's List
#  7       389                                   12 Angry Men
#  8       129                                  Spirited Away
#  9       155                                The Dark Knight
#  10    19404                    Dilwale Dulhania Le Jayenge
#  11   936075                                        Michael
#  12      497                                 The Green Mile
#  13      122  The Lord of the Rings: The Return of the King
#  14   496243                                       Parasite
# ...

# %%
df.to_csv('movies.csv', index=False) # now you can upload to kaggle

# %% [markdown]
# # use rapid api get data convert to csv and upload to kaggle
