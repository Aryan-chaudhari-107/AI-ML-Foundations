# %% [markdown]
# ## 1. Importing pandas

# %%
import pandas as pd

# %% [markdown]
# ## 2. Opening a local csv file

# %%
df = pd.read_csv('file name') 
df
# aug_train.csv --> your csv file name

# %% [markdown]
# ## 3. Opening a csv file from an URL

# %%
import requests
from io import StringIO

url = "" # paste url

headers = {
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"
}

req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)

# %% [markdown]
# ## 4. Sep Parameter

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# consider i have tsv file

pd.read_csv('file name', sep='\t', names=['sno', 'name', 'release_year', 'rating', 'votes','genres']) 
# use name parameter for column name

# %% [markdown]
# ## 5. Index_col parameter

# %%
pd.read_csv('Data/movies.csv').head(3)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                  Battalion 609                  Battalion 609         0
# 2  The Accidental Prime Minister  The Accidental Prime Minister         0
#
# ...

# %%
pd.read_csv('Data/movies.csv', index_col='imdb_id').head(3)
# Out:
#                                         title_x  \
# imdb_id
# tt8291224              Uri: The Surgical Strike
# tt9472208                         Battalion 609
# tt6986710  The Accidental Prime Minister (film)
#
#                                                  poster_path  \
# imdb_id
# tt8291224  https://upload.wikimedia.org/wikipedia/en/thum...
# tt9472208                                                NaN
# tt6986710  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                                    wiki_link  \
# imdb_id
# tt8291224  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# tt9472208        https://en.wikipedia.org/wiki/Battalion_609
# tt6986710  https://en.wikipedia.org/wiki/The_Accidental_P...
#
#                                  title_y                 original_title  \
# imdb_id
# tt8291224       Uri: The Surgical Strike       Uri: The Surgical Strike
# tt9472208                  Battalion 609                  Battalion 609
# ...

# %% [markdown]
# ## 6. Header parameter

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# first row --> column header
pd.read_csv('file name', header = 1)

# %% [markdown]
# ## 7. use_cols parameter

# %%
pd.read_csv('file name', usecols=['enrollee_id', 'x', 'y', 'z'])
# select specific columns

# %% [markdown]
# ## 8. Squeeze parameters

# %%
pd.read_csv('file name', usecols=['gender'], squeeze = True)
# dataframe --> series

# %% [markdown]
# ## 9. Skiprows/nrows Parameter

# %%
pd.read_csv('Data/movies.csv').head(5)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
pd.read_csv('Data/movies.csv', skiprows=[1,3]).head(5)
# Out:
#            title_x    imdb_id  \
# 0    Battalion 609  tt9472208
# 1  Why Cheat India  tt8108208
# 2  Evening Shadows  tt6028796
# 3      Soni (film)  tt6078866
# 4    Fraud Saiyaan  tt5013008
#
#                                          poster_path  \
# 0                                                NaN
# 1  https://upload.wikimedia.org/wikipedia/en/thum...
# 2                                                NaN
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                        wiki_link          title_y  \
# 0    https://en.wikipedia.org/wiki/Battalion_609    Battalion 609
# 1  https://en.wikipedia.org/wiki/Why_Cheat_India  Why Cheat India
# 2  https://en.wikipedia.org/wiki/Evening_Shadows  Evening Shadows
# 3      https://en.wikipedia.org/wiki/Soni_(film)             Soni
# 4    https://en.wikipedia.org/wiki/Fraud_Saiyaan    Fraud Saiyaan
#
# ...

# %%
pd.read_csv('Data/movies.csv', nrows=10)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
# 5                           Soni (film)  tt6078866
# 6                         Fraud Saiyaan  tt5013008
# 7                            Bombairiya  tt4971258
# 8      Manikarnika: The Queen of Jhansi  tt6903440
# 9                      Thackeray (film)  tt7777196
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# ## 10. Encoding parameter

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# if encoding is not utf-8 then find encoding and pass in encoding parameter
pd.read_csv('file name', encoding = '')

# %% [markdown]
# ## 11. Skip bad lines

# %%
# ParserError me use krna hai 
pd.read_csv('file name', error_bad_lines = False)

# %% [markdown]
# ## 12. dtypes parameter

# %%
# defult hota hai but we can overwrite
pd.read_csv('file name', dtype={'column name': int})
# int, float, str etc...

# %% [markdown]
# ## 13. Handling Dates

# %%
pd.read_csv('Data/movies.csv').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
pd.read_csv('Data/movies.csv', parse_dates=['year_of_release']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   datetime64[ns]
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %% [markdown]
# ## 14. Convertors

# %%
pd.read_csv('Data/ipl-matches.csv').head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
def rename(name):
    if name == "Royal Challengers Bangalore":
        return "RCB"
    else:
        return name

df = pd.read_csv('Data/ipl-matches.csv', converters={'Team1': rename})

# %%
df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                      Team1                        Team2  \
# 0         Rajasthan Royals               Gujarat Titans
# 1                      RCB             Rajasthan Royals
# 2                      RCB         Lucknow Super Giants
# ...

# %% [markdown]
# ## 15. na_values parameter

# %%
# na_values = "Convert special values (?, NA, Missing, etc.) into NaN".
pd.read_csv('file name', na_values=['?'])

# %% [markdown]
# ## 16. Loading a huge dataset in chunks

# %%
dfs = pd.read_csv('Data/ipl-matches.csv', chunksize = 500)

# %%
for chunks in dfs:
    print(chunks.shape)
# Out:
# (500, 20)
# (450, 20)
