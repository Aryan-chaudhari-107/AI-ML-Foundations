# %% [markdown]
# ## What is Pandas
#
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.
#
# https://pandas.pydata.org/about/index.html

# %% [markdown]
# ## Pandas Series
#
# A Pandas Series is like a column in a table. It is a 1-D array holding data of any type.

# %% [markdown]
# ## Importing Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Series from lists

# %%
# String
country = ['India', 'Nepal', 'USA', 'Srilanka']

pd.Series(country) # 99% time object dtype is string
# Out:
# 0       India
# 1       Nepal
# 2         USA
# 3    Srilanka
# dtype: object

# %%
# Integers
runs = [13,24, 50, 100, 0]
runs = pd.Series(runs)
runs
# Out:
# 0     13
# 1     24
# 2     50
# 3    100
# 4      0
# dtype: int64

# %%
# Custom Index
marks = [67, 57, 89, 100]
subjects = ['Maths', 'English', 'Sci', 'Hindi']

pd.Series(marks, index=subjects)
# Out:
# Maths       67
# English     57
# Sci         89
# Hindi      100
# dtype: int64

# %%
# Setting a name
marks = pd.Series(marks, index=subjects, name="Aryan K marks")
marks
# Out:
# Maths       67
# English     57
# Sci         89
# Hindi      100
# Name: Aryan K marks, dtype: int64

# %% [markdown]
# ## 2. Series from dict

# %%
marks = {
    'Maths'  :  67, 
    'English':  57, 
    'Sci'    :  89, 
    'Hindi'  : 100
}

marks_series = pd.Series(marks, name = "Aryan K marks")
marks_series
# Out:
# Maths       67
# English     57
# Sci         89
# Hindi      100
# Name: Aryan K marks, dtype: int64

# %% [markdown]
# ## 3. Attributes

# %%
# size (count missing value)
marks_series.size
# Out:
# 4

# %%
# dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
# name
marks_series.name
# Out:
# 'Aryan K marks'

# %%
# is_unique
marks_series.is_unique
# Out:
# True

# %%
pd.Series([1,1,2,2,3,4,5]).is_unique
# Out:
# False

# %%
# index
marks_series.index

runs.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# values
marks_series.values
# Out:
# array([ 67,  57,  89, 100])

# %% [markdown]
# ## 4. Series using read_csv

# %%
import pandas as pd

subs = pd.read_csv('Datasets/subs.csv').squeeze('columns')
subs

# squeeze() is used to convert a single-column DataFrame into a Series.
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# with 2 cols
vk = pd.read_csv('Datasets/kohli_ipl.csv', index_col = 'match_no').squeeze('columns')
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies = pd.read_csv('Datasets/bollywood.csv', index_col = 'movie').squeeze('columns')
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ## 5. Series Methods

# %%
# head and tail

subs.head()
# by defualt top 5
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
vk.head(3)
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# Name: runs, dtype: int64

# %%
vk.tail(5)
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
# sample
movies.sample()
# Out:
# movie
# Guddu Ki Gun    Kunal Khemu
# Name: lead, dtype: object

# %%
movies.sample(5)
# Out:
# movie
# 7½ Phere                       Juhi Chawla
# Na Ghar Ke Na Ghaat Ke             Om Puri
# Aarakshan                 Amitabh Bachchan
# Sirf (film)                  Kay Kay Menon
# Chargesheet (film)               Dev Anand
# Name: lead, dtype: object

# %%
# value_counts --> movies
movies.value_counts()
# Out:
# lead
# Akshay Kumar            48
# Amitabh Bachchan        45
# Ajay Devgn              38
# Salman Khan             31
# Sanjay Dutt             26
#                         ..
# Tanishaa Mukerji         1
# Tanuja                   1
# Ankit                    1
# Rakhee Gulzar            1
# Geetika Vidya Ohlyan     1
# Name: count, Length: 566, dtype: int64

# %%
# sort_value --> inplace
vk.sort_values()
# Out:
# match_no
# 8        0
# 87       0
# 93       0
# 91       0
# 206      0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64

# %%
vk.sort_values(ascending=False)
# Out:
# match_no
# 128    113
# 126    109
# 123    108
# 120    100
# 164    100
#       ...
# 93       0
# 130      0
# 206      0
# 207      0
# 211      0
# Name: runs, Length: 215, dtype: int64

# %%
vk.sort_values(ascending=False).head(1).values[0]
# Out:
# np.int64(113)

# %%
vk.sort_values(inplace=True) # if you want perment changes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 vk.sort_values(inplace=True) # if you want perment changes
#
# File c:\Python_Software\Lib\site-packages\pandas\core\series.py:3857, in Series.sort_values(self, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    3855 # GH 5856/5853
#    3856 if inplace and self._is_cached:
# -> 3857     raise ValueError(
#    3858         "This Series is a view of some other array, to "
#    3859         "sort in-place you must create a copy"
#    3860     )
#    3862 if is_list_like(ascending):
#    3863     ascending = cast(Sequence[bool], ascending)
#
# ValueError: This Series is a view of some other array, to sort in-place you must create a copy

# %%
# sort_index -> inplace -> movie
movies.sort_index()
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %%
movies.sort_index(inplace=True) # perment changes

# %% [markdown]
# ## 6. Series Maths Methods

# %%
# count (don't count missing values)
vk.count()
# Out:
# np.int64(215)

# %%
# sum -> product
subs.sum()
# Out:
# np.int64(0)

# %%
# mean -> median -> mode -> std -> var
vk.mean()
vk.median()
vk.mode()
vk.std()
vk.var()

print(movies.mode())
# Out:
# 0    Akshay Kumar
# Name: lead, dtype: object

# %%
# min/max
vk.min()
vk.max()
# Out:
# np.int64(113)

# %%
# describe
vk.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %%
subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %% [markdown]
# ## 7. Series Indexing

# %%
x = pd.Series([12, 13, 14, 15, 19, 42, 77, 100])
# Out:
# np.int64(42)

# %%
# integer indexing
x[5]
# Out:
# np.int64(42)

# %%
# negative indexing
x.iloc[-1] # iloc always support negative and positive indexing
# Out:
# np.int64(100)

# %%
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies[7]
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_34920\5015865.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   movies[7]
# 'Radhika Apte'

# %%
movies['Battalion 609']
# Out:
# 'Vicky Ahuja'

# %%
movies[-1]
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_34920\2731571422.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   movies[-1]
# 'Akshay Kumar'

# %%
# slicing
vk[5:16]
# Out:
# match_no
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# 11    10
# 12    38
# 13     3
# 14    11
# 15    50
# 16     2
# Name: runs, dtype: int64

# %%
# negative slicing
vk[-5:]
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
movies[-5:]
# Out:
# movie
# Hum Tumhare Hain Sanam      Shah Rukh Khan
# Aankhen (2002 film)       Amitabh Bachchan
# Saathiya (film)               Vivek Oberoi
# Company (film)                  Ajay Devgn
# Awara Paagal Deewana          Akshay Kumar
# Name: lead, dtype: object

# %%
vk[::2]
# Out:
# match_no
# 1       1
# 3      13
# 5       1
# 7      34
# 9      21
#        ..
# 207     0
# 209    58
# 211     0
# 213    73
# 215     7
# Name: runs, Length: 108, dtype: int64

# %%
# fancy indexing
vk[[11,23,24,55]]
# Out:
# match_no
# 11    10
# 23    19
# 24    24
# 55     8
# Name: runs, dtype: int64

# %%
# indexing with lables -> fancy indexing
movies['Evening Shadows']
# Out:
# 'Mona Ambegaonkar'

# %% [markdown]
# ## 8. Editing Series

# %%
# using indexing
marks_series
# Out:
# Maths       67
# English     57
# Sci         89
# Hindi      100
# Name: Aryan K marks, dtype: int64

# %%
marks_series[1] = 100
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_34920\3104910507.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_series[1] = 100

# %%
# what if an index does not exist
marks_series['sst'] = 90
marks_series
# Out:
# Maths       67
# English    100
# Sci         89
# Hindi      100
# sst         90
# Name: Aryan K marks, dtype: int64

# %%
# using slicing
runs
# Out:
# 0     13
# 1     24
# 2     50
# 3    100
# 4      0
# dtype: int64

# %%
runs[2:4]=[100,100]
runs
# Out:
# 0     13
# 1     24
# 2    100
# 3    100
# 4      0
# dtype: int64

# %%
# fancy indexing
runs[[0,3,4]] = [50,50,101]
runs
# Out:
# 0     50
# 1     24
# 2    100
# 3     50
# 4    101
# dtype: int64

# %%
# using index label
movies['2 State (2014 film)'] = 'Alia Bhatt'
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# 2 State (2014 film)                           Alia Bhatt
# Name: lead, Length: 1501, dtype: object

# %% [markdown]
# ## 9. Series with Python Fuctionalitis

# %%
# len/type/dir/sorted/max/min
print(len(subs))
print(type(subs))
print(dir(subs))
print(sorted(subs)) # but store in list
print(min(subs))
print(max(subs))
# Out:
# 365
# <class 'pandas.core.series.Series'>
# ...

# %%
# type conversion
list(marks_series)
# Out:
# [67, 100, 89, 100, 90]

# %%
dict(marks_series)
# Out:
# {'Maths': np.int64(67),
#  'English': np.int64(100),
#  'Sci': np.int64(89),
#  'Hindi': np.int64(100),
#  'sst': np.int64(90)}

# %%
# membership operator
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# 2 State (2014 film)                           Alia Bhatt
# Name: lead, Length: 1501, dtype: object

# %%
'2 State (2014 film)' in movies # in only for index
# Out:
# True

# %%
'Alia Bhatt' in movies
# Out:
# False

# %%
'Alia Bhatt' in movies.values # for search value
# Out:
# True

# %%
# looping
for i in movies: # works on values
    print(i)
# Out:
# Vicky Kaushal
# Vicky Ahuja
# Anupam Kher
# Emraan Hashmi
# Mona Ambegaonkar
# Geetika Vidya Ohlyan
# Arshad Warsi
# Radhika Apte
# Kangana Ranaut
# Nawazuddin Siddiqui
# Ali Asgar
# Ranveer Singh
# Prit Kamani
# Ajay Devgn
# Sushant Singh Rajput
# Amitabh Bachchan
# Abhimanyu Dasani
# Talha Arshad Reshi
# Nawazuddin Siddiqui
# Garima Agarwal
# Rasika Agashe
# Barun Sobti
# Akshay Kumar
# Zaheer Iqbal
# Vidyut Jammwal
# Deepika Amin
# Manav Kaul
# Naseeruddin Shah
# Varun Dhawan
# Shreyas Talpade
# Tiger Shroff
# Boman Irani
# Ajay Devgn
# Arjun Kapoor
# Gavie Chahal
# Prabhu Deva
# Shahid Kapoor
# Ayushmann Khurrana
# Anupam Kher
# Karanvir Bohra
# Hrithik Roshan
# Jimmy Sheirgill
# John Abraham
# Rishi Kapoor
# Kangana Ranaut
# Natalia Janoszek
# Diljit Dosanjh
# Sidharth Malhotra
# Rajeev Khandelwal
# Zaira Wasim
# Akshay Kumar
# Jacqueline Fernandez
# Ayushmann Khurrana
# Akshaye Khanna
# Sonam Kapoor
# Karan Deol
# Sanjay Dutt
# Bhavesh Kumar
# Sanaya Irani
# Ayushmann Khurrana
# ...

# %%
for i in movies.index: # for index
    print(i)
# Out:
# Uri: The Surgical Strike
# Battalion 609
# The Accidental Prime Minister (film)
# Why Cheat India
# Evening Shadows
# Soni (film)
# Fraud Saiyaan
# Bombairiya
# Manikarnika: The Queen of Jhansi
# Thackeray (film)
# Amavas
# Gully Boy
# Hum Chaar
# Total Dhamaal
# Sonchiriya
# Badla (2019 film)
# Mard Ko Dard Nahi Hota
# Hamid (film)
# Photograph (film)
# Risknamaa
# Mere Pyare Prime Minister
# 22 Yards
# Kesari (film)
# Notebook (2019 film)
# Junglee (2019 film)
# Gone Kesh
# Albert Pinto Ko Gussa Kyun Aata Hai?
# The Tashkent Files
# Kalank
# Setters (film)
# Student of the Year 2
# PM Narendra Modi
# De De Pyaar De
# India's Most Wanted (film)
# Yeh Hai India
# Khamoshi (2019 film)
# Kabir Singh
# Article 15 (film)
# One Day: Justice Delivered
# Hume Tumse Pyaar Kitna
# Super 30 (film)
# Family of Thakurganj
# Batla House
# Jhootha Kahin Ka
# Judgementall Hai Kya
# Chicken Curry Law
# Arjun Patiala
# Jabariya Jodi
# Pranaam
# The Sky Is Pink
# Mission Mangal
# Saaho
# ...

# %%
# Arithmetic Operators(Broadcasting)
100 - marks_series # all type of operators works
# Out:
# Maths      33
# English     0
# Sci        11
# Hindi       0
# sst        10
# Name: Aryan K marks, dtype: int64

# %%
# Relational Operators
vk >= 50
# Out:
# match_no
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 211    False
# 212    False
# 213     True
# 214    False
# 215    False
# Name: runs, Length: 215, dtype: bool

# %% [markdown]
# ## 10. Boolean indexing on Series

# %%
# Find no of 50's and 100's scored by kohli
vk[vk >=50 ].size
# Out:
# 50

# %%
# find number of ducks
vk[vk == 0].size
# Out:
# 9

# %%
# Count number of day when I had more than 200 subs a day
subs[subs >= 200].size
# Out:
# 59

# %%
# find actors who have done more than 20 movies
num_movie = movies.value_counts()
num_movie[num_movie > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %% [markdown]
# ## 11. Plotting Graphs on Series

# %%
subs.plot()
# Out:
# <Axes: >

# %%
vk.plot()
# Out:
# <Axes: xlabel='match_no'>

# %%
movies.value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='lead'>

# %% [markdown]
# ## 12. Some Important Seires Mehtods

# %%
# astype
import sys

sys.getsizeof(vk)
# Out:
# 3472

# %%
sys.getsizeof(vk.astype('int16'))
# Out:
# 2182

# %%
# between
vk[vk.between(51, 99)].size #both are included
# Out:
# 43

# %%
# clip
subs.clip(100,200) # values less then 100 becomes 100
# values more then 200 becomes 200
# Out:
# 0      100
# 1      100
# 2      100
# 3      100
# 4      100
#       ...
# 360    200
# 361    200
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# drop_duplicates

temp = pd.Series([0,0,1,2,3,3,4,5])
temp.drop_duplicates()
# Out:
# 0    0
# 2    1
# 3    2
# 4    3
# 6    4
# 7    5
# dtype: int64

# %%
temp.drop_duplicates(keep='last')
# Out:
# 1    0
# 2    1
# 3    2
# 5    3
# 6    4
# 7    5
# dtype: int64

# %%
movies.drop_duplicates()
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Sssshhh...                              Tanishaa Mukerji
# Rules: Pyaar Ka Superhit Formula                  Tanuja
# Right Here Right Now (film)                        Ankit
# Talaash: The Hunt Begins...                Rakhee Gulzar
# The Pink Mirror                          Edwin Fernandes
# Name: lead, Length: 566, dtype: object

# %%
temp.duplicated().sum()
# Out:
# np.int64(2)

# %%
vk.duplicated().sum()
# Out:
# np.int64(137)

# %%
# isnull
temp = pd.Series([1,2,3,np.nan,5,6,np.nan,8,np.nan,10])
temp
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4     5.0
# 5     6.0
# 6     NaN
# 7     8.0
# 8     NaN
# 9    10.0
# dtype: float64

# %%
temp.size
# Out:
# 10

# %%
temp.count()
# Out:
# np.int64(7)

# %%
temp[temp.isnull()]
# Out:
# 3   NaN
# 6   NaN
# 8   NaN
# dtype: float64

# %%
temp.isnull().sum()
# Out:
# np.int64(3)

# %%
# dropna
temp.dropna()
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 4     5.0
# 5     6.0
# 7     8.0
# 9    10.0
# dtype: float64

# %%
# fillna
temp.fillna(temp.mean())
temp.fillna(0)
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     0.0
# 4     5.0
# 5     6.0
# 6     0.0
# 7     8.0
# 8     0.0
# 9    10.0
# dtype: float64

# %%
# isin
vk[(vk==49) | (vk == 99)]
# Out:
# match_no
# 82    99
# 86    49
# Name: runs, dtype: int64

# %%
vk[vk.isin([49,99])]
# Out:
# match_no
# 82    99
# 86    49
# Name: runs, dtype: int64

# %%
# apply
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies.apply(lambda x:x.split()[0].upper())
# Out:
# movie
# Uri: The Surgical Strike                  VICKY
# Battalion 609                             VICKY
# The Accidental Prime Minister (film)     ANUPAM
# Why Cheat India                          EMRAAN
# Evening Shadows                            MONA
#                                          ...
# Hum Tumhare Hain Sanam                     SHAH
# Aankhen (2002 film)                     AMITABH
# Saathiya (film)                           VIVEK
# Company (film)                             AJAY
# Awara Paagal Deewana                     AKSHAY
# Name: lead, Length: 1500, dtype: object

# %%
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
subs.mean()
# Out:
# np.float64(135.64383561643837)

# %%
subs.apply(lambda x:'Good day' if x > subs.mean() else 'Bas day')
# Out:
# 0       Bas day
# 1       Bas day
# 2       Bas day
# 3       Bas day
# 4       Bas day
#          ...
# 360    Good day
# 361    Good day
# 362    Good day
# 363    Good day
# 364    Good day
# Name: Subscribers gained, Length: 365, dtype: object

# %%
# copy 
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
new = vk.head() # head and tail give view of the data and if you change anything it will reflect 
new
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
new[1] = 1

# %%
new
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
##
new = vk.tail().copy() 
new
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
new[215] = 100

# %%
new.tail()
# Out:
# match_no
# 211      0
# 212     20
# 213     73
# 214     25
# 215    100
# Name: runs, dtype: int64

# %%
vk.tail()
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64
